# %%
import numpy as np

from utils.training import plot_log
# Out:
# Using TensorFlow backend.

# %%
checkdir = './checkpoints/201806162129_crnn_lstm_synthtext'
checkdir = './checkpoints/201806190711_crnn_gru_synthtext'
plot_log(checkdir + '/log.json', ['loss'], [100, np.inf], window_length=2000)
# Out:
# ./checkpoints/201806190711_crnn_gru_synthtext/log.json
# ['loss']
# time per epoch 4.6 h

# %%
checkdir1 = './checkpoints/201806162129_crnn_lstm_synthtext'
checkdir2 = './checkpoints/201806190711_crnn_gru_synthtext'

plot_log(checkdir1+'/log.json', ['loss'], [0, np.inf], window_length=2000, log_file_compare=checkdir2+'/log.json')
# Out:
# ./checkpoints/201806162129_crnn_lstm_synthtext/log.json
# ./checkpoints/201806190711_crnn_gru_synthtext/log.json
# ['loss']
# time per epoch 5.4 h
