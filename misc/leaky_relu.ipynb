# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
alpha = 0.1

x = np.arange(-10, 11)
y = alpha * np.minimum(x, 0) + np.maximum(x, 0)

plt.figure()
plt.plot(x, x)
plt.plot(x, y)
ax = plt.gca()
ax.grid()
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
plt.show()
